# %%
import pandas as pd
import seaborn as sns
from sklearn.datasets import make_blobs

# Generate some random data
X, y = make_blobs(n_samples=500, centers=4, cluster_std=0.7)

# Create a scatterplot of the data with cluster colors
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, data=data)
# Out:
# <Axes: >
